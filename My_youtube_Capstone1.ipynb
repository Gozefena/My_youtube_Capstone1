# %% [markdown]
# source: https://www.kaggle.com/hoonkeng/deep-analysis-on-youtube-trending-videos-eda/notebook

# %%
import os
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# %%
# !dir
# Out:
#  Volume in drive C is OS
#  Volume Serial Number is 720C-2AF3
#
#  Directory of C:\Users\Gozefena\Desktop\Galvanize\Capstone1
#
# 09/25/2019  09:24 AM    <DIR>          .
# 09/25/2019  09:24 AM    <DIR>          ..
# 09/23/2019  04:29 PM    <DIR>          .ipynb_checkpoints
# 09/25/2019  09:24 AM            25,710 My_youtube_Capstone1.ipynb
#                1 File(s)         25,710 bytes
#                3 Dir(s)  317,018,210,304 bytes free

# %%
path = 'Capstone1_Data'
filename1 = os.path.join('..',path,'dataframe.csv')
filename2 = os.path.join('..',path,'dataframe_all_timestamps.csv')


df = pd.read_csv(filename1)
df_all_timestamps = pd.read_csv(filename2)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 171149 entries, 0 to 171148
# Data columns (total 19 columns):
# video_id                  171149 non-null object
# trending_date             171149 non-null object
# title                     171149 non-null object
# channel_title             171149 non-null object
# category_id               171149 non-null int64
# category                  171149 non-null object
# publish_date              171149 non-null object
# publish_time              171149 non-null object
# tags                      171149 non-null object
# views                     171149 non-null int64
# likes                     171149 non-null int64
# dislikes                  171149 non-null int64
# comment_count             171149 non-null int64
# thumbnail_link            171149 non-null object
# comments_disabled         171149 non-null bool
# ratings_disabled          171149 non-null bool
# video_error_or_removed    171149 non-null bool
# ...

# %%
df_all_timestamps.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 356350 entries, 0 to 356349
# Data columns (total 19 columns):
# video_id                  356350 non-null object
# trending_date             356350 non-null object
# title                     356350 non-null object
# channel_title             356350 non-null object
# category_id               356350 non-null int64
# category                  356350 non-null object
# publish_date              356350 non-null object
# publish_time              356350 non-null object
# tags                      356350 non-null object
# views                     356350 non-null int64
# likes                     356350 non-null int64
# dislikes                  356350 non-null int64
# comment_count             356350 non-null int64
# thumbnail_link            356350 non-null object
# comments_disabled         356350 non-null bool
# ratings_disabled          356350 non-null bool
# video_error_or_removed    356350 non-null bool
# ...

# %%
df.head(10)
# Out:
#       video_id trending_date  \
# 0  cJon8yBKv3g    2017-11-14
# 1  g12KeCPRB4Q    2017-11-14
# 2  irIZRH3JlIw    2017-11-14
# 3  SnHtzkQZggA    2017-11-14
# 4  u6EoWM2KMPE    2017-11-14
# 5  k0OruM7tneA    2017-11-14
# 6  z4PWAu9HfxM    2017-11-14
# 7  4HeOSihd32A    2017-11-14
# 8  _wChN4yabJM    2017-11-14
# 9  3KvSVqN43t0    2017-11-14
#
#                                                title  \
# 0     Kingsman : Le Cercle d'or (Mickael J Critique)
# 1               Vide grenier LIVE - 12 Novembre 2017
# 2  لقجع يثور في وجه الإتحاد الإيفواري بسبب الجماه...
# 3   عروس اسطنبول | اعلان الحلقة 25 | - مترجم للعربية
# 4  Portokalli, 12 Nentor 2017 - Policat e postbll...
# 5  الإعلام المصري :  شكون فالمنتخبات العربية  لي ...
# 6                               No hablo (Vidéoclip)
# 7  LES GAMERS [Version intégrale] - Les Reportage...
# 8  DALS S08 - Lenni-Kim danse un Tango avec Denit...
# 9             VOL, BAGARRE ET CRACHAT - Draw My Life
#
# ...

# %% [markdown]
# Below Pandas Dataframe/Series.head() method. Pandas head(3) method is used to return top 3 rows of a data frame or series. I am looking for the first 3 rows to get acquainted with the data.

# %%
df_all_timestamps.head(3)
# Out:
#       video_id trending_date                                           title  \
# 0  n1WpP7iowLc    2017-11-14      Eminem - Walk On Water (Audio) ft. Beyoncé
# 1  cJon8yBKv3g    2017-11-14  Kingsman : Le Cercle d'or (Mickael J Critique)
# 2  g12KeCPRB4Q    2017-11-14            Vide grenier LIVE - 12 Novembre 2017
#
#     channel_title  category_id          category publish_date publish_time  \
# 0      EminemVEVO           10             Music   2017-11-10     17:00:03
# 1  MJ - FERMEZ LA            1  Film & Animation   2017-11-12     17:58:57
# 2        Kirby-54           20            Gaming   2017-11-12     13:46:18
#
#                                                 tags     views   likes  \
# 0  Eminem|"Walk"|"On"|"Water"|"Aftermath/Shady/In...  17158579  787425
# 1  VoxMakers"|"FERMEZ LA"|"Alert Spoiler"|"Matthe...     19487    1596
# 2  Vide grenier"|"vide grenier live"|"brocante"|"...     20744    1032
#
# ...

# %% [markdown]
# Below I use iloc[] method to look at a slice of df, so I can get acquainted with the data.

# %%
df.iloc[100000:100012]
# Out:
#            video_id trending_date  \
# 100000  JxxUmYLWnig    2018-03-17
# 100001  P0SB54UZ_yM    2018-03-17
# 100002  eYPQXon_UKQ    2018-03-17
# 100003  HoRujp6-lF0    2018-03-17
# 100004  ALOyzCuhRGI    2018-03-17
# 100005  sQ3r7jp8fyk    2018-03-17
# 100006  _1r_86BkH5g    2018-03-17
# 100007  A7VrWCkLTDc    2018-03-17
# 100008  BPFKdTU4GQk    2018-03-17
# 100009  A3tOel2vGZU    2018-03-17
# 100010  iK0n0lkhhWI    2018-03-17
# 100011  1gRr8nJzK7I    2018-03-17
#
#                                                     title     channel_title  \
# 100000                       Nabález, Morat - La Correcta       NabalezVEVO
# 100001  Reporte Sísmico: OAXACA - Volcán Submarino Sim...        Tenshi Mex
# 100002               Reto 4 elementos | Inicia este lunes  Reto 4 Elementos
# 100003           KENDALL JENNER CANTA ACERCA de SU VÂGlNÂ      Chicas Cosmo
# 100004                                EL ERROR DE HAWKING         Doc Files
# ...

# %% [markdown]
# Below I use tail() method to look at a bottom of df, so I can get acquainted with a bottom the data,by default it is 5.

# %%
df.tail()
# Out:
#            video_id trending_date  \
# 171144  qLM1NA272v0    2018-06-14
# 171145  xpP9TR0M5e8    2018-06-14
# 171146  WxJ4SfmUGgY    2018-06-14
# 171147  znUg17W526o    2018-06-14
# 171148  ooyjaVdt-jA    2018-06-14
#
#                                                     title    channel_title  \
# 171144  حصري/ شاهد ماذا فعل مشجعون مغاربة بتركي آل شيخ...         Elbotola
# 171145  Nach 37 Sekunden passiert etwas im Ofen, das j...  Leckerschmecker
# 171146  НЕРЯХА ДЖО! БУРГЕР для детей и взрослых (здоро...         oblomoff
# 171147                      Die Wahrheit über die WM 2018      MrWissen2go
# 171148  Official Call of Duty®: Black Ops 4 — Multipla...     Call of Duty
#
#         category_id        category publish_date publish_time  \
# 171144           17          Sports   2018-06-13     20:59:22
# 171145           26   Howto & Style   2018-06-13     16:30:03
# 171146           24   Entertainment   2018-06-13     11:04:35
# ...

# %% [markdown]
# Create a column with length of video description.

# %%
df['descr_len'] = df['description'].str.len()
df
# Out:
#            video_id trending_date  \
# 0       cJon8yBKv3g    2017-11-14
# 1       g12KeCPRB4Q    2017-11-14
# 2       irIZRH3JlIw    2017-11-14
# 3       SnHtzkQZggA    2017-11-14
# 4       u6EoWM2KMPE    2017-11-14
# ...             ...           ...
# 171144  qLM1NA272v0    2018-06-14
# 171145  xpP9TR0M5e8    2018-06-14
# 171146  WxJ4SfmUGgY    2018-06-14
# 171147  znUg17W526o    2018-06-14
# 171148  ooyjaVdt-jA    2018-06-14
#
#                                                     title  \
# 0          Kingsman : Le Cercle d'or (Mickael J Critique)
# 1                    Vide grenier LIVE - 12 Novembre 2017
# 2       لقجع يثور في وجه الإتحاد الإيفواري بسبب الجماه...
# 3        عروس اسطنبول | اعلان الحلقة 25 | - مترجم للعربية
# 4       Portokalli, 12 Nentor 2017 - Policat e postbll...
# ...                                                   ...
# 171144  حصري/ شاهد ماذا فعل مشجعون مغاربة بتركي آل شيخ...
# 171145  Nach 37 Sekunden passiert etwas im Ofen, das j...
# ...

# %% [markdown]
# Pandas Dataframe.describe() method Pandas is one of those packages and makes importing and analyzing data much easier. Pandas describe() is used to view some basic statistical details like percentile, mean, std etc. of a data frame or a series of numeric values. Below let's look at the numbers.

# %%
df.describe()
# Out:
#          category_id         views         likes      dislikes  comment_count  \
# count  171149.000000  1.711490e+05  1.711490e+05  1.711490e+05   1.711490e+05
# mean       20.922576  3.628359e+05  1.010452e+04  6.533677e+02   1.304655e+03
# std         6.753576  2.888626e+06  5.417935e+04  6.348801e+03   7.834437e+03
# min         1.000000  1.530000e+02  0.000000e+00  0.000000e+00   0.000000e+00
# 25%        20.000000  2.263500e+04  3.460000e+02  2.100000e+01   5.500000e+01
# 50%        24.000000  7.664000e+04  1.498000e+03  7.900000e+01   2.350000e+02
# 75%        24.000000  2.424700e+05  5.830000e+03  2.900000e+02   8.320000e+02
# max        44.000000  4.245389e+08  5.613827e+06  1.753274e+06   1.228655e+06
#
#            descr_len
# count  171149.000000
# mean      800.058656
# std       835.311361
# min         1.000000
# 25%       225.000000
# 50%       536.000000
# 75%      1065.000000
# max      5369.000000

# %% [markdown]
# Create an auxiliary dataframe with only numerical data.

# %%
df_num = df.select_dtypes(np.number)
df_num
# Out:
#         category_id     views   likes  dislikes  comment_count  descr_len
# 0                 1     19487    1596        23            215        288
# 1                20     20744    1032       558            243        375
# 2                25    207452    1415       148             90        216
# 3                 1     15899     142        10              7        344
# 4                23    100607    1159        48             35         42
# ...             ...       ...     ...       ...            ...        ...
# 171144           17    179322    1890       346           2229        447
# 171145           26     29630    1029        36             55       1922
# 171146           24    587480   35688      1207           2380        529
# 171147           22    164294    9065       453           1632       2073
# 171148           20  10306119  357079    212976         144795        709
#
# [171149 rows x 6 columns]

# %% [markdown]
# Delete category_id column since it's categorical in essence, not numerical

# %%
df_num_drop = df_num.drop(columns=['category_id'])
# Out:
#            views   likes  dislikes  comment_count  descr_len
# 0          19487    1596        23            215        288
# 1          20744    1032       558            243        375
# 2         207452    1415       148             90        216
# 3          15899     142        10              7        344
# 4         100607    1159        48             35         42
# ...          ...     ...       ...            ...        ...
# 171144    179322    1890       346           2229        447
# 171145     29630    1029        36             55       1922
# 171146    587480   35688      1207           2380        529
# 171147    164294    9065       453           1632       2073
# 171148  10306119  357079    212976         144795        709
#
# [171149 rows x 5 columns]

# %%
df_num.head()
# Out:
#    category_id   views  likes  dislikes  comment_count  descr_len
# 0            1   19487   1596        23            215        288
# 1           20   20744   1032       558            243        375
# 2           25  207452   1415       148             90        216
# 3            1   15899    142        10              7        344
# 4           23  100607   1159        48             35         42

# %% [markdown]
# Below let's trancate dataframe with conditional statement (.loc)

# %%
df.max()
# Out:
# video_id                                                        zzz0_5fMnI8
# trending_date                                                    2018-06-14
# title                     🧐8k Bitcoin rote Woche? Ethereum, Digibyte, Ve...
# channel_title                                                      💜Sandrea
# category_id                                                              44
# category                                                    Travel & Events
# publish_date                                                     2018-06-14
# publish_time                                                       23:59:58
# tags                                                    🚀 smartpixel.com.ua
# views                                                             424538912
# likes                                                               5613827
# dislikes                                                            1753274
# ...

# %%
df_truncated = df.loc[df['likes'] >= 3000000 ]
df_truncated
# Out:
#            video_id trending_date  \
# 32380   FlsCjmMhFmw    2017-12-24
# 105767  kLpH1nSLJSs    2018-03-23
# 107307  xpVfcZ0ZcFM    2018-03-25
# 155749  ffxKSjUwKdU    2018-05-26
# 160289  7C2z4GqqS5E    2018-06-01
# 167397  VYOjWnS4cMY    2018-06-11
#
#                                                     title  \
# 32380   YouTube Rewind: The Shape of 2017 | #YouTubeRe...
# 105767               Bad Bunny - Amorfoda | Video Oficial
# 107307                                 Drake - God’s Plan
# 155749               Ariana Grande - No Tears Left To Cry
# 160289                BTS (방탄소년단) 'FAKE LOVE' Official MV
# 167397  Childish Gambino - This Is America (Official V...
#
#               channel_title  category_id       category publish_date  \
# 32380     YouTube Spotlight           24  Entertainment   2017-12-06
# 105767            Bad Bunny           10          Music   2018-02-15
# 107307            DrakeVEVO           10          Music   2018-02-17
# ...

# %% [markdown]
# Trying to create histogram over numerical data -> looks "beautiful"

# %%
for column in df_num.columns:
    fig = plt.figure(figsize=(10,4))
    sns.distplot(df_num[column], color = "y",  bins = 50)

# %%
df_num_simple = df_num[df_num['likes']<5000]

# %%
# sns.distplot(df_num['likes'],bins=50000).set(xlim=(0,5000))
sns.distplot(df_num_simple['likes'],bins=100).set(xlim=(0,1000), ylim=(0,.004))
# Out:
# [(0, 0.004), (0, 1000)]

# %%
sns.relplot(x = "likes", y = "category", data = df)

# %%
df_new = df_truncated[['views','likes','dislikes']]
df_new
df_new.head()
# Out:
#             views    likes  dislikes
# 32380   169884583  3312868   1753274
# 105767  328860380  3823879    215530
# 107307  258164991  4737873    117198
# 155749  208876887  3394437    150086
# 160289  123010920  5613827    206892

# %%
df_truncated['likes(millions)'] = df_truncated['likes']/1000000
df_truncated.head()
# Out:
# c:\users\gozefena\miniconda3\lib\site-packages\ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """Entry point for launching an IPython kernel.
#            video_id trending_date  \
# 32380   FlsCjmMhFmw    2017-12-24
# 105767  kLpH1nSLJSs    2018-03-23
# 107307  xpVfcZ0ZcFM    2018-03-25
# 155749  ffxKSjUwKdU    2018-05-26
# 160289  7C2z4GqqS5E    2018-06-01
#
#                                                     title      channel_title  \
# 32380   YouTube Rewind: The Shape of 2017 | #YouTubeRe...  YouTube Spotlight
# 105767               Bad Bunny - Amorfoda | Video Oficial          Bad Bunny
# 107307                                 Drake - God’s Plan          DrakeVEVO
# ...

# %%
g = sns.scatterplot(x = 'channel_title', y = 'likes(millions)', data = df_truncated, hue='channel_title')
plt.setp(g.get_xticklabels(),rotation=90)
# Out:
# [None, None, None, None, None, None, None, None, None, None, None, None]
